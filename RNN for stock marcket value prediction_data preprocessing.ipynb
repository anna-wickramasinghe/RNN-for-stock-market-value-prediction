# %%
import pandas as pd
df = pd.read_csv('AAPL.csv')
df.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 1254  2024-01-29  192.009995  192.199997  189.580002  191.729996  191.729996
# 1255  2024-01-30  190.940002  191.800003  187.470001  188.039993  188.039993
# 1256  2024-01-31  187.039993  187.100006  184.350006  184.399994  184.399994
# 1257  2024-02-01  183.990005  186.949997  183.820007  186.860001  186.860001
# 1258  2024-02-02  179.860001  187.330002  179.250000  185.850006  185.850006
#
#          Volume
# 1254   47145600
# 1255   55859400
# 1256   55467800
# 1257   64885400
# 1258  102518000

# %%
close_value = df.values[:,4]
close_value
# Out:
# array([42.8125, 43.544998, 43.560001, ..., 184.399994, 186.860001,
#        185.850006], dtype=object)

# %%
close_value.shape
# Out:
# (1259,)

# %%
import matplotlib.pyplot as plt
plt.plot(close_value[:300])
plt.show()

# %%
close_value = close_value.reshape(-1,1)

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
scaled_close_value = scaler.fit_transform(close_value)

# %%
close_value.shape
# Out:
# (1259, 1)

# %%
data = []
target = []

window_size = 50

for i in range(0,len(close_value)-window_size):
    data.append(scaled_close_value[i:i+window_size])
    target.append(scaled_close_value[i+window_size])

# %%
np.save('data',data)
np.save('target',target)

# %%
import joblib
joblib.dump(scaler, 'models\scaler.sav')
# Out:
# ['models\\scaler.sav']
